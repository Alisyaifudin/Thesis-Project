# %%
import vaex
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from glob import glob
from os.path import join, abspath
from os import pardir
import sys
from scipy.stats import norm

# %%
root_dir = abspath(join(pardir, pardir))
if root_dir not in sys.path:
    sys.path.append(root_dir)
sys.path
# Out:
# ['/home2/s20321005/Thesis-Project/4_Vertical_Number/no',
#  '/home2/s20321005/.conda/envs/vaex/lib/python38.zip',
#  '/home2/s20321005/.conda/envs/vaex/lib/python3.8',
#  '/home2/s20321005/.conda/envs/vaex/lib/python3.8/lib-dynload',
#  '',
#  '/home2/s20321005/.local/lib/python3.8/site-packages',
#  '/home2/s20321005/.conda/envs/vaex/lib/python3.8/site-packages',
#  '/home2/s20321005/Thesis-Project']

# %%
from utils import safe_mkdir

# %% [markdown]
# dir paths

# %%
root_data_dir = abspath(join(root_dir, "Data"))
twomass_dir = join(root_data_dir, "TMASS")
gaia_dir = join(root_data_dir, "Best-Pars")

# %% [markdown]
# completeness path

# %%
data_dir = join(root_data_dir, "Completeness")
safe_mkdir(data_dir)
name = "no"
data_dir = join(root_data_dir, "Completeness", name)
safe_mkdir(data_dir)
# Out:
# Directory /home2/s20321005/Thesis-Project/Data/Completeness already exist. Good to go!
# Directory /home2/s20321005/Thesis-Project/Data/Completeness/no already exist. Good to go!

# %% [markdown]
# twomass files path

# %%
twomass_files = glob(join(twomass_dir, "*.hdf5"))
twomass_files.sort()
twomass_files[:5]
# Out:
# ['/home2/s20321005/Thesis-Project/Data/TMASS/tmass-000-001.hdf5',
#  '/home2/s20321005/Thesis-Project/Data/TMASS/tmass-001-002.hdf5',
#  '/home2/s20321005/Thesis-Project/Data/TMASS/tmass-002-003.hdf5',
#  '/home2/s20321005/Thesis-Project/Data/TMASS/tmass-003-004.hdf5',
#  '/home2/s20321005/Thesis-Project/Data/TMASS/tmass-004-005.hdf5']

# %% [markdown]
# add JK as color

# %%
tmass = vaex.open_many(twomass_files)
tmass["JK"] = tmass["Jmag"] - tmass["Kmag"]
tmass = tmass.extract()
tmass
# Out:
# #           designation       use_src    rd_flg    ra          dec         Jmag    Kmag    ph_qual    JK
# 0           00000036-0848119  1          222       0.001505    -8.803321   13.041  12.539  AAA        0.5020008
# 1           00000135-0828045  1          222       0.005649    -8.467934   13.285  12.946  AAA        0.33899975
# 2           00000182-0806237  1          222       0.007621    -8.106606   12.34   12.006  AAA        0.3340006
# 3           00000409-0854339  1          222       0.017071    -8.909436   13.434  12.841  AAA        0.5930004
# 4           00000432-0837071  1          222       0.018027    -8.618639   11.935  11.584  AAA        0.3510008
# ...         ...               ...        ...       ...         ...         ...     ...     ...        ...
# 50,250,394  23594291-7708495  1          222       359.928833  -77.14711   10.942  10.558  AAA        0.38400078
# 50,250,395  23594324-7738278  1          212       359.93019   -77.64106   9.331   8.665   AAA        0.66600037
# 50,250,396  23594896-7715221  1          222       359.954028  -77.256149  13.336  12.843  AAA        0.49300003
# 50,250,397  23594907-7751479  1          222       359.954495  -77.863312  13.261  12.619  AAA        0.64199924
# 50,250,398  23595757-7750396  1          222       359.989904  -77.844337  13.203  12.728  AAA        0.47500038

# %% [markdown]
# Let's see the heatmap count of twomass

# %%
tmass.viz.heatmap("JK", "Jmag", shape=100, show=True, limits=[[-0.5, 1], [0, 13.5]], f='log')

# %% [markdown]
# filter out only for A quality

# %% [markdown]
# ## Check at each color range

# %%
tmass_filt = tmass.filter("JK <0.1").filter("JK > 0")
tmass_filt = tmass_filt.extract()
tmass_filt.viz.histogram("Jmag", shape=100, show=True, limits=[0, 13.5], f='log')

# %% [markdown]
# looks nice to me!

# %% [markdown]
# # gaia

# %%
gaia_files = glob(join(gaia_dir, "gaia-*.hdf5"))
gaia_files.sort()
gaia_files[:5]
# Out:
# ['/home2/s20321005/Thesis-Project/Data/Best-Pars/gaia-000-001.hdf5',
#  '/home2/s20321005/Thesis-Project/Data/Best-Pars/gaia-001-002.hdf5',
#  '/home2/s20321005/Thesis-Project/Data/Best-Pars/gaia-002-003.hdf5',
#  '/home2/s20321005/Thesis-Project/Data/Best-Pars/gaia-003-004.hdf5',
#  '/home2/s20321005/Thesis-Project/Data/Best-Pars/gaia-004-005.hdf5']

# %% [markdown]
# load gaia

# %%
gaia = vaex.open_many(gaia_files)
gaia
# Out:
# #           ra          dec         Jmag                Kmag                ph_qual    source_id            pm                  pmra                 e_pmra                pmdec                e_pmdec               parallax            e_parallax            gmag                bpmag               rpmag               fb_over_err        fr_over_err         ruwe                excess_factor       GLON                GLAT                 distance_gspphot    distance_gspphot_lower    distance_gspphot_upper    ag_gspphot           ag_gspphot_lower     ag_gspphot_upper     fem_gspspec           fem_gspspec_lower    fem_gspspec_upper      spectraltype_esphs    designation       use_src    rd_flg    subclass_lamost    rv                   rv_cat    rv_el               rv_eu               rv_sym    teff              teff_cat    teff_el          teff_eu         teff_sym    logg                logg_cat    logg_el               logg_eu                logg_sym    feh    feh_cat    feh_el    feh_eu    feh_sym    mh                    mh_cat    mh_el                 mh_eu                 mh_sym    alphafe               alphafe_cat    alphafe_el    alphafe_eu            alphafe_sym    alpham    alpham_cat    alpham_el    alpham_eu    alpham_sym
# 0           0.180498    -89.243835  13.123000144958496  12.678999900817871  AAA        4611967772579686144  18.71722984313965   17.611683049974353   0.017649758607149124  -6.337454890038764   0.018100611865520477  1.553482146463873   0.01645069755613804   14.506683349609375  14.941158294677734  13.901935577392578  927.3828125        1271.326416015625   0.9241908192634583  1.2207494974136353  303.11950730746855  -27.865822360149586  586.5784301757812   580.6773071289062         592.7108764648438         0.44209998846054077  0.4359000027179718   0.4494999945163727   nan                   nan                  nan                    G                     00004331-8914378  1          222       --                 152.84475708007812   gaia      4.919384002685547   4.919384002685547   1.0       5675.6103515625   gspphot     11.37353515625   13.83251953125  0.0         4.49429988861084    gspphot     0.006199836730957031  0.004800319671630859   0.0         nan    --         nan       nan       nan        -0.5550000071525574   gspphot   0.016799986362457275  0.01639997959136963   0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan
# 1           0.338177    -89.481033  8.97700023651123    8.038000106811523   AAA        4611761957746621312  9.622093200683594   7.609580877064016    0.014360921457409859  -5.888883602727228   0.014550801366567612  0.8273958945757836  0.012673814781010151  11.280521392822266  12.197066307067871  10.340993881225586  1234.30517578125   3648.09716796875    1.0564011335372925  1.3118351697921753  303.05891462343493  -27.634759739425405  1171.7508544921875  1142.204345703125         1543.05419921875          0.8133999705314636   0.6207000017166138   0.8633999824523926   -0.12999999523162842  -0.2199999988079071  -0.029999999329447746  K                     00012116-8928517  1          111       --                 30.259687423706055   gaia      0.167822003364563   0.167822003364563   1.0       4251.74755859375  gspphot     142.98876953125  39.806640625    0.0         2.018699884414673   gspphot     0.2597998380661011    0.024700164794921875   0.0         nan    --         nan       nan       nan        0.11720000207424164   gspphot   0.006000004708766937  0.002799995243549347  0.0       -0.05000000074505806  gspspec        0.0           0.010000001639127731  0.0            nan       --            nan          nan          nan
# 2           0.392894    -89.286575  12.769000053405762  12.329999923706055  AAA        4611779756091083008  6.918576717376709   4.89813965086399     0.01557445153594017   -4.88619823091078    0.016693463549017906  1.4919122615226004  0.015075388364493847  14.183528900146484  14.626376152038574  13.570565223693848  865.9398193359375  1384.228271484375   1.063724160194397   1.2225970029830933  303.10597686099044  -27.824720661451884  625.9152221679688   620.0595703125            631.713623046875          0.5141000151634216   0.5109000205993652   0.5171999931335449   nan                   nan                  nan                    G                     00013429-8917116  1          222       --                 8.28650951385498     gaia      6.514820575714111   6.514820575714111   1.0       5750.4326171875   gspphot     5.1650390625     4.8857421875    0.0         4.354100227355957   gspphot     0.006400108337402344  0.006499767303466797   0.0         nan    --         nan       nan       nan        -0.2969000041484833   gspphot   0.007499992847442627  0.006400018930435181  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan
# 3           0.491097    -89.325348  13.28499984741211   12.92199993133545   AAA        4611778656579457664  3.3354551792144775  2.758184654146036    0.015947440639138222  1.8755476312609647   0.01630321703851223   0.9132976622425212  0.014618651941418648  14.359504699707031  14.703383445739746  13.843310356140137  1021.37451171875   1692.3876953125     0.975788950920105   1.2055027484893799  303.09523730720935  -27.787137577515743  1043.23193359375    1028.8033447265625        1058.512939453125         0.3813000023365021   0.37709999084472656  0.3856000006198883   nan                   nan                  nan                    F                     00015786-8919312  1          222       --                 -9.221250534057617   gaia      6.796242713928223   6.796242713928223   1.0       6268.86279296875  gspphot     7.986328125      8.31982421875   0.0         4.254300117492676   gspphot     0.012599945068359375  0.012599945068359375   0.0         nan    --         nan       nan       nan        -0.36550000309944153  gspphot   0.005600005388259888  0.005600005388259888  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan
# 4           0.140988    -88.624542  12.574000358581543  12.22599983215332   AAA        4612059856678435456  7.222960948944092   6.909171651019708    0.014309556223452091  -2.105828540221265   0.01369965448975563   1.142868834794636   0.012145737186074257  13.668671607971191  14.005749702453613  13.163238525390625  1205.94580078125   2095.777587890625   1.006279706954956   1.2021443843841553  303.27634091220216  -28.469529127008617  858.9404296875      850.015625                867.8400268554688         0.29989999532699585  0.2937000095844269   0.30649998784065247  nan                   nan                  nan                    F                     00003383-8837283  1          222       --                 33.83838653564453    gaia      3.4127907752990723  3.4127907752990723  1.0       6146.64794921875  gspphot     13.3173828125    13.89794921875  0.0         4.204100131988525   gspphot     0.007100105285644531  0.0067996978759765625  0.0         nan    --         nan       nan       nan        -0.5670999884605408   gspphot   0.014299988746643066  0.01569998264312744   0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan
# ...         ...         ...         ...                 ...                 ...        ...                  ...                 ...                  ...                   ...                  ...                   ...                 ...                   ...                 ...                 ...                 ...                ...                 ...                 ...                 ...                 ...                  ...                 ...                       ...                       ...                  ...                  ...                  ...                   ...                  ...                    ...                   ...               ...        ...       ...                ...                  ...       ...                 ...                 ...       ...               ...         ...              ...             ...         ...                 ...         ...                   ...                    ...         ...    ...        ...       ...       ...        ...                   ...       ...                   ...                   ...       ...                   ...            ...           ...                   ...            ...       ...           ...          ...          ...
# 29,144,413  359.121617  88.849464   12.791000366210938  12.413999557495117  AAA        2305490791832146432  4.029613971710205   -0.8951470378522143  0.01455365028232336   -3.9289311748326035  0.017279088497161865  0.5963603953551687  0.013008298352360725  14.046445846557617  14.441862106323242  13.479680061340332  961.6585693359375  1206.795166015625   0.9792236685752869  1.213295340538025   122.62790640386665  26.010265744280915   1395.16064453125    1381.1881103515625        1421.57666015625          0.41940000653266907  0.4066999852657318   0.4284000098705292   nan                   nan                  nan                    G                     23562918+8850580  1          222       --                 -4.409039497375488   gaia      3.751502752304077   3.751502752304077   1.0       5864.337890625    gspphot     25.02880859375   16.6455078125   0.0         3.7739999294281006  gspphot     0.018399953842163086  0.010499954223632812   0.0         nan    --         nan       nan       nan        -0.5562999844551086   gspphot   0.021600008010864258  0.010500013828277588  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan
# 29,144,414  359.476859  88.387932   13.071999549865723  12.65999984741211   AAA        2304711581685346432  10.118563652038574  9.746954357302645    0.019540144130587578  -2.71702261816708    0.01730901189148426   1.192541824142351   0.015409919433295727  14.306392669677734  14.693642616271973  13.742040634155273  970.5338745117188  1503.42529296875    0.9179697036743164  1.2155245542526245  122.51842977553947  25.55932221031494    821.5986938476562   810.9293212890625         831.757080078125          0.22869999706745148  0.21960000693798065  0.23479999601840973  nan                   nan                  nan                    G                     23575444+8823165  1          222       --                 -78.52452850341797   gaia      4.588349342346191   4.588349342346191   1.0       5545.29443359375  gspphot     16.857421875     11.61083984375  0.0         4.261600017547607   gspphot     0.007599830627441406  0.00820016860961914    0.0         nan    --         nan       nan       nan        -1.2724000215530396   gspphot   0.025499939918518066  0.021600008010864258  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan
# 29,144,415  359.704935  88.155998   12.468999862670898  11.920000076293945  AAA        2304646710499313408  24.277976989746094  24.276081384949727   0.017281681299209595  -0.3033332281423549  0.016044413670897484  2.635903040983505   0.014043435454368591  14.101089477539062  14.674555778503418  13.384231567382812  492.229736328125   828.0851440429688   1.025539517402649   1.2422640323638916  122.46781764928367  25.33183850890207    376.3951110839844   374.2648010253906         378.823486328125          0.36890000104904175  0.36059999465942383  0.37860000133514404  nan                   nan                  nan                    K                     23584918+8809215  1          222       --                 -8.928035736083984   gaia      2.753666400909424   2.753666400909424   1.0       4983.408203125    gspphot     13.6767578125    17.49560546875  0.0         4.507900238037109   gspphot     0.004500389099121094  0.004599571228027344   0.0         nan    --         nan       nan       nan        -0.16740000247955322  gspphot   0.012299999594688416  0.013999998569488525  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan
# 29,144,416  359.799848  88.985268   12.97599983215332   12.267999649047852  AAA        2305539513941136000  10.311738967895508  -1.1558347554809572  0.024979863315820694  10.246756138155417   0.02309444360435009   2.8844735007745492  0.021700281649827957  14.88602066040039   15.639410018920898  14.045271873474121  331.0479431152344  406.3185729980469   0.9543192386627197  1.2754230499267578  122.67651932514369  26.139580203151045   349.3190002441406   343.58599853515625        353.6755065917969         0.4090000092983246   0.4002000093460083   0.41620001196861267  nan                   nan                  nan                    K                     23591196+8859069  1          222       --                 -27.380125045776367  gaia      9.952363967895508   9.952363967895508   1.0       4487.59130859375  gspphot     6.55322265625    6.748046875     0.0         4.625199794769287   gspphot     0.009899616241455078  0.014400005340576172   0.0         nan    --         nan       nan       nan        0.48969998955726624   gspphot   0.01850000023841858   0.007600009441375732  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan
# 29,144,417  359.909394  88.295273   13.086999893188477  12.508000373840332  AAA        2304698318826339328  19.401451110839844  18.986569146748128   0.02199697680771351   3.990799827264129    0.020262878388166428  0.6766671974315497  0.017869945615530014  14.728175163269043  15.290057182312012  14.016490936279297  662.81298828125    1084.6163330078125  0.9303231239318848  1.2429786920547485  122.50893317096917  25.46627153250137    1211.0174560546875  1188.0755615234375        1242.2559814453125        0.6851000189781189   0.6751000285148621   0.699400007724762    nan                   nan                  nan                    K                     23593825+8817429  1          222       --                 -0.3641735315322876  gaia      8.3587646484375     8.3587646484375     1.0       5366.36328125     gspphot     16.30517578125   26.08251953125  0.0         4.070799827575684   gspphot     0.008699893951416016  0.006700038909912109   0.0         nan    --         nan       nan       nan        -0.23350000381469727  gspphot   0.02369999885559082   0.025700002908706665  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan

# %% [markdown]
# let's see the sky distribution using healpix.
#
# Gaia data have special column called `source_id` which can be transformed into healpix index. Let's see the distribution of the data.

# %%
import healpy as hp

level = 6
factor = 34359738368 * (4**(12-level))
nmax = hp.nside2npix(2**level)
epsilon = 1e-16
counts = gaia.count(binby=gaia.source_id/factor, limits=[-epsilon, nmax-epsilon], shape=nmax)
counts
# Out:
# array([129, 153, 150, ..., 388, 393, 388])

# %%
gaia.viz.healpix_heatmap(
    f="log",
    healpix_level=6,
    figsize=(10,8),
    healpix_output="galactic"
)

# %% [markdown]
# add color JK

# %%
gaia['JK'] = gaia['Jmag'] - gaia['Kmag']
gaia
# Out:
# #           ra          dec         Jmag                Kmag                ph_qual    source_id            pm                  pmra                 e_pmra                pmdec                e_pmdec               parallax            e_parallax            gmag                bpmag               rpmag               fb_over_err        fr_over_err         ruwe                excess_factor       GLON                GLAT                 distance_gspphot    distance_gspphot_lower    distance_gspphot_upper    ag_gspphot           ag_gspphot_lower     ag_gspphot_upper     fem_gspspec           fem_gspspec_lower    fem_gspspec_upper      spectraltype_esphs    designation       use_src    rd_flg    subclass_lamost    rv                   rv_cat    rv_el               rv_eu               rv_sym    teff              teff_cat    teff_el          teff_eu         teff_sym    logg                logg_cat    logg_el               logg_eu                logg_sym    feh    feh_cat    feh_el    feh_eu    feh_sym    mh                    mh_cat    mh_el                 mh_eu                 mh_sym    alphafe               alphafe_cat    alphafe_el    alphafe_eu            alphafe_sym    alpham    alpham_cat    alpham_el    alpham_eu    alpham_sym    JK
# 0           0.180498    -89.243835  13.123000144958496  12.678999900817871  AAA        4611967772579686144  18.71722984313965   17.611683049974353   0.017649758607149124  -6.337454890038764   0.018100611865520477  1.553482146463873   0.01645069755613804   14.506683349609375  14.941158294677734  13.901935577392578  927.3828125        1271.326416015625   0.9241908192634583  1.2207494974136353  303.11950730746855  -27.865822360149586  586.5784301757812   580.6773071289062         592.7108764648438         0.44209998846054077  0.4359000027179718   0.4494999945163727   nan                   nan                  nan                    G                     00004331-8914378  1          222       --                 152.84475708007812   gaia      4.919384002685547   4.919384002685547   1.0       5675.6103515625   gspphot     11.37353515625   13.83251953125  0.0         4.49429988861084    gspphot     0.006199836730957031  0.004800319671630859   0.0         nan    --         nan       nan       nan        -0.5550000071525574   gspphot   0.016799986362457275  0.01639997959136963   0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan           0.444000244140625
# 1           0.338177    -89.481033  8.97700023651123    8.038000106811523   AAA        4611761957746621312  9.622093200683594   7.609580877064016    0.014360921457409859  -5.888883602727228   0.014550801366567612  0.8273958945757836  0.012673814781010151  11.280521392822266  12.197066307067871  10.340993881225586  1234.30517578125   3648.09716796875    1.0564011335372925  1.3118351697921753  303.05891462343493  -27.634759739425405  1171.7508544921875  1142.204345703125         1543.05419921875          0.8133999705314636   0.6207000017166138   0.8633999824523926   -0.12999999523162842  -0.2199999988079071  -0.029999999329447746  K                     00012116-8928517  1          111       --                 30.259687423706055   gaia      0.167822003364563   0.167822003364563   1.0       4251.74755859375  gspphot     142.98876953125  39.806640625    0.0         2.018699884414673   gspphot     0.2597998380661011    0.024700164794921875   0.0         nan    --         nan       nan       nan        0.11720000207424164   gspphot   0.006000004708766937  0.002799995243549347  0.0       -0.05000000074505806  gspspec        0.0           0.010000001639127731  0.0            nan       --            nan          nan          nan           0.939000129699707
# 2           0.392894    -89.286575  12.769000053405762  12.329999923706055  AAA        4611779756091083008  6.918576717376709   4.89813965086399     0.01557445153594017   -4.88619823091078    0.016693463549017906  1.4919122615226004  0.015075388364493847  14.183528900146484  14.626376152038574  13.570565223693848  865.9398193359375  1384.228271484375   1.063724160194397   1.2225970029830933  303.10597686099044  -27.824720661451884  625.9152221679688   620.0595703125            631.713623046875          0.5141000151634216   0.5109000205993652   0.5171999931335449   nan                   nan                  nan                    G                     00013429-8917116  1          222       --                 8.28650951385498     gaia      6.514820575714111   6.514820575714111   1.0       5750.4326171875   gspphot     5.1650390625     4.8857421875    0.0         4.354100227355957   gspphot     0.006400108337402344  0.006499767303466797   0.0         nan    --         nan       nan       nan        -0.2969000041484833   gspphot   0.007499992847442627  0.006400018930435181  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan           0.43900012969970703
# 3           0.491097    -89.325348  13.28499984741211   12.92199993133545   AAA        4611778656579457664  3.3354551792144775  2.758184654146036    0.015947440639138222  1.8755476312609647   0.01630321703851223   0.9132976622425212  0.014618651941418648  14.359504699707031  14.703383445739746  13.843310356140137  1021.37451171875   1692.3876953125     0.975788950920105   1.2055027484893799  303.09523730720935  -27.787137577515743  1043.23193359375    1028.8033447265625        1058.512939453125         0.3813000023365021   0.37709999084472656  0.3856000006198883   nan                   nan                  nan                    F                     00015786-8919312  1          222       --                 -9.221250534057617   gaia      6.796242713928223   6.796242713928223   1.0       6268.86279296875  gspphot     7.986328125      8.31982421875   0.0         4.254300117492676   gspphot     0.012599945068359375  0.012599945068359375   0.0         nan    --         nan       nan       nan        -0.36550000309944153  gspphot   0.005600005388259888  0.005600005388259888  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan           0.36299991607666016
# 4           0.140988    -88.624542  12.574000358581543  12.22599983215332   AAA        4612059856678435456  7.222960948944092   6.909171651019708    0.014309556223452091  -2.105828540221265   0.01369965448975563   1.142868834794636   0.012145737186074257  13.668671607971191  14.005749702453613  13.163238525390625  1205.94580078125   2095.777587890625   1.006279706954956   1.2021443843841553  303.27634091220216  -28.469529127008617  858.9404296875      850.015625                867.8400268554688         0.29989999532699585  0.2937000095844269   0.30649998784065247  nan                   nan                  nan                    F                     00003383-8837283  1          222       --                 33.83838653564453    gaia      3.4127907752990723  3.4127907752990723  1.0       6146.64794921875  gspphot     13.3173828125    13.89794921875  0.0         4.204100131988525   gspphot     0.007100105285644531  0.0067996978759765625  0.0         nan    --         nan       nan       nan        -0.5670999884605408   gspphot   0.014299988746643066  0.01569998264312744   0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan           0.34800052642822266
# ...         ...         ...         ...                 ...                 ...        ...                  ...                 ...                  ...                   ...                  ...                   ...                 ...                   ...                 ...                 ...                 ...                ...                 ...                 ...                 ...                 ...                  ...                 ...                       ...                       ...                  ...                  ...                  ...                   ...                  ...                    ...                   ...               ...        ...       ...                ...                  ...       ...                 ...                 ...       ...               ...         ...              ...             ...         ...                 ...         ...                   ...                    ...         ...    ...        ...       ...       ...        ...                   ...       ...                   ...                   ...       ...                   ...            ...           ...                   ...            ...       ...           ...          ...          ...           ...
# 29,144,413  359.121617  88.849464   12.791000366210938  12.413999557495117  AAA        2305490791832146432  4.029613971710205   -0.8951470378522143  0.01455365028232336   -3.9289311748326035  0.017279088497161865  0.5963603953551687  0.013008298352360725  14.046445846557617  14.441862106323242  13.479680061340332  961.6585693359375  1206.795166015625   0.9792236685752869  1.213295340538025   122.62790640386665  26.010265744280915   1395.16064453125    1381.1881103515625        1421.57666015625          0.41940000653266907  0.4066999852657318   0.4284000098705292   nan                   nan                  nan                    G                     23562918+8850580  1          222       --                 -4.409039497375488   gaia      3.751502752304077   3.751502752304077   1.0       5864.337890625    gspphot     25.02880859375   16.6455078125   0.0         3.7739999294281006  gspphot     0.018399953842163086  0.010499954223632812   0.0         nan    --         nan       nan       nan        -0.5562999844551086   gspphot   0.021600008010864258  0.010500013828277588  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan           0.3770008087158203
# 29,144,414  359.476859  88.387932   13.071999549865723  12.65999984741211   AAA        2304711581685346432  10.118563652038574  9.746954357302645    0.019540144130587578  -2.71702261816708    0.01730901189148426   1.192541824142351   0.015409919433295727  14.306392669677734  14.693642616271973  13.742040634155273  970.5338745117188  1503.42529296875    0.9179697036743164  1.2155245542526245  122.51842977553947  25.55932221031494    821.5986938476562   810.9293212890625         831.757080078125          0.22869999706745148  0.21960000693798065  0.23479999601840973  nan                   nan                  nan                    G                     23575444+8823165  1          222       --                 -78.52452850341797   gaia      4.588349342346191   4.588349342346191   1.0       5545.29443359375  gspphot     16.857421875     11.61083984375  0.0         4.261600017547607   gspphot     0.007599830627441406  0.00820016860961914    0.0         nan    --         nan       nan       nan        -1.2724000215530396   gspphot   0.025499939918518066  0.021600008010864258  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan           0.4119997024536133
# 29,144,415  359.704935  88.155998   12.468999862670898  11.920000076293945  AAA        2304646710499313408  24.277976989746094  24.276081384949727   0.017281681299209595  -0.3033332281423549  0.016044413670897484  2.635903040983505   0.014043435454368591  14.101089477539062  14.674555778503418  13.384231567382812  492.229736328125   828.0851440429688   1.025539517402649   1.2422640323638916  122.46781764928367  25.33183850890207    376.3951110839844   374.2648010253906         378.823486328125          0.36890000104904175  0.36059999465942383  0.37860000133514404  nan                   nan                  nan                    K                     23584918+8809215  1          222       --                 -8.928035736083984   gaia      2.753666400909424   2.753666400909424   1.0       4983.408203125    gspphot     13.6767578125    17.49560546875  0.0         4.507900238037109   gspphot     0.004500389099121094  0.004599571228027344   0.0         nan    --         nan       nan       nan        -0.16740000247955322  gspphot   0.012299999594688416  0.013999998569488525  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan           0.5489997863769531
# 29,144,416  359.799848  88.985268   12.97599983215332   12.267999649047852  AAA        2305539513941136000  10.311738967895508  -1.1558347554809572  0.024979863315820694  10.246756138155417   0.02309444360435009   2.8844735007745492  0.021700281649827957  14.88602066040039   15.639410018920898  14.045271873474121  331.0479431152344  406.3185729980469   0.9543192386627197  1.2754230499267578  122.67651932514369  26.139580203151045   349.3190002441406   343.58599853515625        353.6755065917969         0.4090000092983246   0.4002000093460083   0.41620001196861267  nan                   nan                  nan                    K                     23591196+8859069  1          222       --                 -27.380125045776367  gaia      9.952363967895508   9.952363967895508   1.0       4487.59130859375  gspphot     6.55322265625    6.748046875     0.0         4.625199794769287   gspphot     0.009899616241455078  0.014400005340576172   0.0         nan    --         nan       nan       nan        0.48969998955726624   gspphot   0.01850000023841858   0.007600009441375732  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan           0.7080001831054688
# 29,144,417  359.909394  88.295273   13.086999893188477  12.508000373840332  AAA        2304698318826339328  19.401451110839844  18.986569146748128   0.02199697680771351   3.990799827264129    0.020262878388166428  0.6766671974315497  0.017869945615530014  14.728175163269043  15.290057182312012  14.016490936279297  662.81298828125    1084.6163330078125  0.9303231239318848  1.2429786920547485  122.50893317096917  25.46627153250137    1211.0174560546875  1188.0755615234375        1242.2559814453125        0.6851000189781189   0.6751000285148621   0.699400007724762    nan                   nan                  nan                    K                     23593825+8817429  1          222       --                 -0.3641735315322876  gaia      8.3587646484375     8.3587646484375     1.0       5366.36328125     gspphot     16.30517578125   26.08251953125  0.0         4.070799827575684   gspphot     0.008699893951416016  0.006700038909912109   0.0         nan    --         nan       nan       nan        -0.23350000381469727  gspphot   0.02369999885559082   0.025700002908706665  0.0       nan                   --             nan           nan                   nan            nan       --            nan          nan          nan           0.5789995193481445

# %% [markdown]
# and the heatmap

# %%
gaia.viz.heatmap("JK", "Jmag", shape=100, show=True, limits=[[-0.5, 1], [0, 13.5]], f='log')

# %% [markdown]
# looks similar to 2MASS.
#
# Let's compare them!

# %%
gaia_filt = gaia.filter("JK <0.1").filter("JK > 0")
gaia_filt = gaia_filt.extract()
gaia_filt.viz.histogram("Jmag", shape=100, label="gaia", limits=[0, 13.5], f='log')
tmass_filt.viz.histogram("Jmag", shape=100, label="tmass", limits=[0, 13.5], f='log')
plt.legend()

# %% [markdown]
# # Let's do some math
#
# We are going to fit them for each color range.

# %%
from utils import load_spectral_types

# %%
spectral_types = load_spectral_types()
spectral_types
# Out:
#       SpT    M_J    J-H   H-Ks    J-K
# 0     O9V  -3.44 -0.164 -0.071 -0.235
# 1   O9.5V  -3.30 -0.161 -0.069 -0.230
# 2     B0V  -3.17 -0.159 -0.067 -0.226
# 3   B0.5V  -2.80 -0.153 -0.063 -0.216
# 4     B1V  -2.33 -0.148 -0.059 -0.207
# ..    ...    ...    ...    ...    ...
# 95    T6V  15.34  0.100 -0.030  0.070
# 96    T7V  15.83  0.000  0.000  0.000
# 97  T7.5V  16.61  0.200 -0.050  0.150
# 98    T8V  17.30  0.200 -0.050  0.150
# 99    T9V  18.51  0.100 -0.200 -0.100
#
# [100 rows x 5 columns]

# %%
jk_bound = np.load(join(root_data_dir, "boundaries.npy"))
jk_bound
# Out:
# array([[-0.019     ,  0.12713703],
#        [ 0.12713703,  0.19024014],
#        [ 0.19024014,  0.22021412],
#        [ 0.22021412,  0.24230021],
#        [ 0.24230021,  0.26004796],
#        [ 0.26004796,  0.27621813],
#        [ 0.27621813,  0.28923315],
#        [ 0.28923315,  0.30106498],
#        [ 0.30106498,  0.31329121],
#        [ 0.31329121,  0.32512304],
#        [ 0.32512304,  0.3353773 ],
#        [ 0.3353773 ,  0.34523716],
#        [ 0.34523716,  0.35509702],
#        [ 0.35509702,  0.36535128],
#        [ 0.36535128,  0.37402796]])

# %%
from tqdm import tqdm
from scipy import interpolate

j_edge = np.linspace(2, 13.5, 100)
js = (j_edge[1:] + j_edge[:-1])/2
dj = j_edge[1] - j_edge[0]
for jk_low, jk_high in jk_bound:
    name = f"comp_({jk_low:.03f})_({jk_high:.03f}).hdf5"
    tmass_filt = tmass.filter(f"JK <{jk_high}").filter(f"JK > {jk_low}")
    tmass_filt = tmass_filt.extract()
    tmass_J = tmass_filt.Jmag.to_numpy()
    tmass_H, _ = np.histogram(tmass_J, bins=j_edge)
    gaia_filt = gaia.filter(f"JK <{jk_high}").filter(f"JK > {jk_low}")
    gaia_filt = gaia_filt.extract()
    gaia_J = gaia_filt.Jmag.to_numpy()
    gaia_H, _ = np.histogram(gaia_J, bins=j_edge)
    
    plt.bar(js, np.log(tmass_H), width=dj, label="tmass", alpha=0.4, edgecolor='k')
    plt.bar(js, np.log(gaia_H), width=dj, label="gaia", alpha=0.4, edgecolor='k')
    plt.legend()
    plt.title(name)
    plt.show()
    mask = (gaia_H == 0) | (tmass_H == 0)
    comp = gaia_H/tmass_H
    comp[comp > 1] = 1
    comp[mask] = 0
    plt.bar(js, comp, width=dj, alpha=0.4, edgecolor='k')
    plt.title(name)
    plt.show()
    print(name)
    df = vaex.from_arrays(j=js, comp=comp)
    df.export(join(data_dir, name), progress=True)
# Out:
# comp_(-0.019)_(0.127).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.03s =  0.0m =  0.0h
# comp_(0.127)_(0.190).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.190)_(0.220).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.220)_(0.242).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.242)_(0.260).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.260)_(0.276).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.276)_(0.289).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.289)_(0.301).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.301)_(0.313).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.313)_(0.325).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.325)_(0.335).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.335)_(0.345).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.345)_(0.355).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.355)_(0.365).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
# comp_(0.365)_(0.374).hdf5
# export(hdf5) [########################################] 100.00% elapsed time  :     0.01s =  0.0m =  0.0h
